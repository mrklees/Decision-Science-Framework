# %% [markdown]
# # Finding parameters for an asymmetric distribution given a 90% CI
#
# This is helpful when an expert will give you a 90% CI and a mean for a particular distribution, and you need to infer its parmeters.  This finds the optimum through a simple hill climbing method.

# %%
from DecisionScienceFramework.utils import DistFinder

# %%
finder = DistFinder(lower=1000, upper=500000, ev=25000, dist='Lognormal')
params = finder.optimize()
finder.summary()
finder.plot_fit()
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# The fit parameters for this lognormal are mu: 10.36389263159178, s: 1.6455013321216245
# The fit distribution has a mean of 122728.50871771961 and a 90% CI of (2116.002125141881, 474729.98363788886).

# %%
finder = DistFinder(lower=0.2, upper=.6, ev=.3, dist='Beta')
params = finder.optimize((1, 10))
finder.summary()
finder.plot_fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.005192
#          Iterations: 54
#          Function evaluations: 104
# The fit parameters for this beta are alpha: 4.949310877252054, beta: 8.937069863593647
# The fit distribution has a mean of 0.3564147469105498 and a 90% CI of (0.16442202068878242, 0.5727254452254109).
